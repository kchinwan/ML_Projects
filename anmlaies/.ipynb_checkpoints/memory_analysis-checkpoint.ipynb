# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# /Users/kuldeepchinwan/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('write_read_ops.csv')

# %%
df = df[df['metricType'] == 'Read Ops']

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values(by=['host','timestamp'])

# %%
df_host = (df.groupby(['host','timestamp'], as_index=False)['value'].max().rename(columns={'value':'read_ops'}))

# %%
# --- Step 4: fill missing timestamps per host ---
cleaned = []
for host, g in df_host.groupby('host'):
    g = g.set_index('timestamp')
    # full 1-min range for this host
    full_index = pd.date_range(start=g.index.min(), end=g.index.max(), freq='1min')
    g = g.reindex(full_index)
    g['host'] = host
    # interpolate small gaps
    g['read_ops'] = g['read_ops'].interpolate(limit=3)
    cleaned.append(g.reset_index().rename(columns={'index':'timestamp'}))

df_host = pd.concat(cleaned, ignore_index=True)

# %%
# --- Step 5: drop duplicates ---
df_host = df_host.drop_duplicates(subset=['host','timestamp'])

# %%
# --- Step 6: fix impossible values ---
df_host['read_ops'] = df_host['read_ops'].clip(lower=0)
upper = df_host['read_ops'].quantile(0.999)  # cap extreme spikes
df_host['read_ops'] = df_host['read_ops'].clip(upper=upper)

# %%
# --- Step 7: optional normalization per host ---
df_host['read_ops_norm'] = 0.0
for host, g in df_host.groupby('host'):
    scaler = StandardScaler()
    normed = scaler.fit_transform(g[['read_ops']])
    df_host.loc[df_host['host']==host, 'read_ops_norm'] = normed

# %%
df_host.describe()
# Out:
#                  timestamp     read_ops  read_ops_norm
# count                10019  9787.000000   9.787000e+03
# mean   2025-08-27 06:00:00   163.469570  -3.484832e-17
# min    2025-08-23 18:31:00     0.033000  -4.182241e-01
# 25%    2025-08-25 12:15:30    20.046500  -3.670108e-01
# 50%    2025-08-27 06:00:00    84.476000  -2.021397e-01
# 75%    2025-08-28 23:44:30   168.640000   1.323081e-02
# max    2025-08-30 17:29:00  5103.188204   1.264044e+01
# std                    NaN   390.807017   1.000051e+00

# %%
# Plot one host for full week
host_id = df_host['host'].unique()[0]
subset = df_host[df_host['host']==host_id]

plt.figure(figsize=(15,5))
plt.plot(subset['timestamp'], subset['read_ops'], label='read_ops')
plt.title(f"read Ops - {host_id}")
plt.xlabel("Time")
plt.ylabel("Ops/sec")
plt.legend()
plt.show()

# %%
pivot = df_host.pivot(index='timestamp', columns='host', values='read_ops')
plt.figure(figsize=(12,6))
sns.heatmap(pivot.isna().T, cbar=False)
plt.title("Missing Data per Host")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='host', y='read_ops', data=df_host)
plt.title("Distribution of read Ops per Host")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10,5))
sns.histplot(df_host['read_ops'], bins=50, kde=True)
plt.title("Histogram of read Ops (All Hosts)")
plt.show()
# Out:
# /Users/kuldeepchinwan/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
subset = subset.set_index('timestamp').asfreq('1min')
subset = subset.dropna()
result = seasonal_decompose(subset['read_ops'], model='additive', period=1440)  # 1440 min = 1 day
result.plot()
plt.show()

# %%
df_host.to_csv('processed_read_ops_db.csv')
